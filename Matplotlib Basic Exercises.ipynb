# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
# Write a Python program to draw a line with suitable label in the x axis, y axis and a title
# %matplotlib inline
df = pd.DataFrame({'x' : range(10,60,10)})
df['y'] = df['x'] * 3
plt.title('Draw a Line')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(df.x, df.y)
plt.show()

# %%
# Write a Python program to draw a line using given axis values with suitable label in the x axis , y axis and a title
# %matplotlib inline
x = [1,2,3]
y = [2,4,1]
plt.title("Simple Graph")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.xticks(np.arange(1,3.5,0.5))
plt.plot(x,y)

plt.show()

# %%
# Write a Python program to draw a line using given axis values with suitable label in the x axis , y axis and a title test.txt
# %matplotlib inline
with open('test.txt') as f:
    data = f.read()
data = data.split('\n')
x = [row.split(' ')[0] for row in data]
y = [row.split(' ')[1] for row in data]
plt.plot(x,y)
plt.title('Simple graph!')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
#Write a Python program to draw line charts of the financial data of Alphabet Inc. between October 3, 2016 to October 7, 2016.Sample Financial data (fdata.csv):
# %matplotlib inline
df = pd.read_csv('fdata.csv')
df.plot()
plt.show()

# %%
#Write a Python program to plot two or more lines on same plot with suitable legends of each line
# %matplotlib inline
x = [10,20,30]
y1 = [20,40,20]
y2 = [40,10,30]
plt.xticks(np.arange(10,35,5))
plt.yticks(np.arange(10,45,5))
plt.plot(x,y1, color = 'blue', label = 'line1')
plt.plot(x,y2, color = 'green', label = 'line2')
plt.title("Two or more lines on same plot with suitable legends")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.show()

# %%
#Write a Python program to plot two or more lines with legends, different widths and colors
# %matplotlib inline
x = [10,20,30]
y1 = [20,40,20]
y2 = [40,10,30]
plt.xticks(np.arange(10,35,5))
plt.yticks(np.arange(10,45,5))
plt.plot(x,y1, color = 'blue', label = 'line1-width-3', lw=3)
plt.plot(x,y2, color = 'red', label = 'line2-width-5', lw=5)
plt.title("Two or more lines on same plot with suitable legends")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.show()

# %%
# Write a Python program to plot two or more lines with different styles
# %matplotlib inline
x = [10,20,30]
y1 = [20,40,20]
y2 = [40,10,30]
plt.xticks(np.arange(10,35,5))
plt.yticks(np.arange(10,45,5))
plt.plot(x,y1, color = 'blue', label = 'line1-dotted', linestyle = 'dotted')
plt.plot(x,y2, color = 'red', label = 'line2-dashed', linestyle = '--')
plt.title("Two or more lines on same plot with suitable legends")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.show()

# %%
# Write a Python program to plot two or more lines and set the line markers
# %matplotlib inline 
x = [1,4,5,6,7]
y = [2,6,3,6,3]
plt.yticks(np.arange(1,15))
plt.ylim(1,8)
plt.xlim(1,8)
plt.plot(x,y, color='red', marker='.', markerfacecolor = 'blue', linestyle = 'dashdot', markersize=15)
plt.show()

# %%
#Write a Python program to display the current axis limits values and set new axis values
# %matplotlib inline
df = pd.DataFrame({'x' : range(1,51)})
df['y'] = df['x'] * 3
plt.plot(df.x, df.y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Draw a line.')
plt.axis([0, 100, 0, 200]) 
plt.show()

# %%
# Write a Python program to plot quantities which have an x and y position.
# %matplotlib inline
x1 = [2, 3, 5, 6, 8]
y1 = [1, 5, 10, 18, 20]
x2 = [3, 4, 6, 7, 9]
y2 = [2, 6, 11, 20, 22]
plt.axis([0,10,0,30])
plt.scatter(x1,y1)
plt.scatter(x2,y2)
plt.show()

# %%
# Write a Python program to plot several lines with different format styles in one command using arrays.
# %matplotlib inline
l = np.arange(0., 5., 0.2)
plt.plot(l,l, 'g--', l,l**2, 'bs', l,l**3, 'r^')
plt.show()

# %%
# Write a Python program to create multiple types of charts (a simple curve and plot some quantities) on a single set of axes.
# %matplotlib inline
import datetime as dt 
from matplotlib.dates import date2num
data = [(dt.datetime.strptime('2016-10-03', "%Y-%m-%d"), 772.559998),
        (dt.datetime.strptime('2016-10-04', "%Y-%m-%d"), 776.429993),
        (dt.datetime.strptime('2016-10-05', "%Y-%m-%d"), 776.469971),
        (dt.datetime.strptime('2016-10-06', "%Y-%m-%d"), 776.859985),
        (dt.datetime.strptime('2016-10-07', "%Y-%m-%d"), 775.080017 )]

x = [date2num(data) for (data, value) in data]
y = [value for (date, value) in data]
graph = plt.figure().add_subplot(111)
plt.plot(x,y,'r-o', markeredgecolor = 'blue')
plt.xticks(x)
graph.set_xticklabels(
        [date.strftime("%Y-%m-%d") for (date, value) in data]
        )
plt.show()

# %%
# Write a Python program to display the grid and draw line charts of the closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with linestyle -, width .5. and color blue
# %matplotlib inline
import datetime as dt 
from matplotlib.dates import date2num
data = [(dt.datetime.strptime('2016-10-03', "%Y-%m-%d"), 772.559998),
        (dt.datetime.strptime('2016-10-04', "%Y-%m-%d"), 776.429993),
        (dt.datetime.strptime('2016-10-05', "%Y-%m-%d"), 776.469971),
        (dt.datetime.strptime('2016-10-06', "%Y-%m-%d"), 776.859985),
        (dt.datetime.strptime('2016-10-07', "%Y-%m-%d"), 775.080017 )]
x = [date2num(data) for (data, value) in data]
y = [value for (date, value) in data]
graph = plt.figure().add_subplot(111)
plt.plot(x,y,'r-o', markeredgecolor = 'blue')
plt.xticks(x)
plt.grid(color='blue', lw=0.5)
plt.title('Closing stock value of Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Closing Value')
graph.set_xticklabels(
        [date.strftime("%Y-%m-%d") for (date, value) in data]
        )
plt.show()

# %%
#Write a Python program to display the grid and draw line charts of the closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with rendering with a larger grid (major grid) and a smaller grid (minor grid).Turn on the grid but turn off ticks.
import datetime as dt 
from matplotlib.dates import date2num
data = [(dt.datetime.strptime('2016-10-03', "%Y-%m-%d"), 772.559998),
        (dt.datetime.strptime('2016-10-04', "%Y-%m-%d"), 776.429993),
        (dt.datetime.strptime('2016-10-05', "%Y-%m-%d"), 776.469971),
        (dt.datetime.strptime('2016-10-06', "%Y-%m-%d"), 776.859985),
        (dt.datetime.strptime('2016-10-07', "%Y-%m-%d"), 775.080017 )]
x = [date2num(data) for (data, value) in data]
y = [value for (date, value) in data]
graph = plt.figure().add_subplot(111)
plt.plot(x,y,'r-o', markeredgecolor = 'blue')
plt.xticks(x)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title('Closing stock value of Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('Closing Value')
graph.set_xticklabels(
        [date.strftime("%Y-%m-%d") for (date, value) in data]
        )
plt.show()

# %%
# Write a Python program to create multiple plots.
# %matplotlib inline
plt.subplot(2,1,1)
plt.xticks(())
plt.yticks(())
plt.subplot(2,3,4)
plt.xticks(())
plt.yticks(())
plt.subplot(2,3,5)
plt.xticks(())
plt.yticks(())
plt.subplot(2,3,6)
plt.xticks(())
plt.yticks(())
plt.show()
